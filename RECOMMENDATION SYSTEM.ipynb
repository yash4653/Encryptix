# %% [markdown]
# # RECOMMEDATION SYSTEM

# %% [markdown]
# # YASH SARIN

# %%
import pandas as pd
import numpy as np

# %%
credits = pd.read_csv("movie.csv")
rating = pd.read_csv("rating.csv")

# %%
movies_df = pd.read_csv("movie.csv")
rating_df = pd.read_csv("rating.csv")

# %%
movies_df = pd.read_csv("movie.csv")

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
credits.head()
rating.head()
# Out:
#    UserId  MovieId  Rating   Timestamp
# 0       1    68646      10  1381620027
# 1       1   113277      10  1379466669
# 2       2   454876       8  1394818630
# 3       2   790636       7  1389963947
# 4       2   816711       8  1379963769

# %%
movies_df.head()
rating_df.head()
# Out:
#    UserId  MovieId  Rating   Timestamp
# 0       1    68646      10  1381620027
# 1       1   113277      10  1379466669
# 2       2   454876       8  1394818630
# 3       2   790636       7  1389963947
# 4       2   816711       8  1379963769

# %%
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
print("Credits:",credits.shape)
print("Movies Dataframe:",movies_df.shape)
# Out:
# Credits: (4803, 4)
# Movies Dataframe: (4803, 4)

# %%
print("Credits:",credits.shape)
print("Movies Dataframe:",movies_df.shape)
print("Rating:",rating.shape)
print("Rating Dataframe:",rating_df.shape)
# Out:
# Credits: (4803, 4)
# Movies Dataframe: (4803, 4)
# Rating: (227472, 4)
# Rating Dataframe: (227472, 4)

# %%
credits_column_renamed = credits.rename(index=str , columns={"movie_id":"id"})
movies_df_merge =movies_df.merge(credits_column_renamed,on='crew')
movies_df_merge.head()
# Out:
#    movie_id                                   title_x  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                               cast_x  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew      id  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...   19995
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...     285
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...  206647
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...   49026
# ...

# %%
credits_column_renamed = credits.rename(index=str , columns={"movie_id":"id"})
movies_df_merge =movies_df.merge(credits_column_renamed,on='crew')
movies_df_merge.head()
rating_column_renamed = rating.rename(index=str , columns={"user_id":"id"})
rating_df_merge =rating_df.merge(rating_column_renamed,on='Timestamp')
movies_df_merge.head()
# Out:
#    movie_id                                   title_x  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                               cast_x  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew      id  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...   19995
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...     285
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...  206647
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...   49026
# ...

# %%
movies_cleaned_df = movies_df_merge.drop(columns=['cast_x','title_x','title_y','crew','cast_y'])
movies_cleaned_df.head()
# Out:
#    movie_id      id
# 0     19995   19995
# 1       285     285
# 2    206647  206647
# 3     49026   49026
# 4     49529   49529

# %%
movies_cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5559 entries, 0 to 5558
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  5559 non-null   int64
#  1   id        5559 non-null   int64
# dtypes: int64(2)
# memory usage: 130.3 KB

# %%
movie=pd.read_csv('movie.csv')
movie.head()
ratings = pd.read_csv("rating.csv")
ratings.head()
# Out:
#    UserId  MovieId  Rating   Timestamp
# 0       1    68646      10  1381620027
# 1       1   113277      10  1379466669
# 2       2   454876       8  1394818630
# 3       2   790636       7  1389963947
# 4       2   816711       8  1379963769

# %%
movie=pd.read_csv('movie.csv',usecols=['movie_id'])
movie.head()
# Out:
#    movie_id
# 0     19995
# 1       285
# 2    206647
# 3     49026
# 4     49529

# %%
movie=pd.read_csv('movie.csv',usecols=['movie_id','title','cast'])
movie.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...

# %%
movie.pivot(index='title',columns='movie_id',values='cast')
# Out:
# movie_id                   5      11     12     13     14     16     18      \
# title
# #Horror                       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# (500) Days of Summer          NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10 Cloverfield Lane           NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10 Days in a Madhouse         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10 Things I Hate About You    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...                           ...    ...    ...    ...    ...    ...    ...
# [REC]²                        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# eXistenZ                      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# xXx                           NaN    NaN    NaN    NaN    NaN    NaN    NaN
# xXx: State of the Union       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Æon Flux                      NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
movie.pivot(index='title',columns='movie_id',values='cast').fillna(0)
# Out:
# movie_id                   5      11     12     13     14     16     18      \
# title
# #Horror                         0      0      0      0      0      0      0
# (500) Days of Summer            0      0      0      0      0      0      0
# 10 Cloverfield Lane             0      0      0      0      0      0      0
# 10 Days in a Madhouse           0      0      0      0      0      0      0
# 10 Things I Hate About You      0      0      0      0      0      0      0
# ...                           ...    ...    ...    ...    ...    ...    ...
# [REC]²                          0      0      0      0      0      0      0
# eXistenZ                        0      0      0      0      0      0      0
# xXx                             0      0      0      0      0      0      0
# xXx: State of the Union         0      0      0      0      0      0      0
# Æon Flux                        0      0      0      0      0      0      0
#
# ...

# %%
movies_users=movie.pivot(index='title',columns='movie_id',values='cast').fillna(0)
movies_users.head()
# Out:
# movie_id                   5      11     12     13     14     16     18      \
# title
# #Horror                         0      0      0      0      0      0      0
# (500) Days of Summer            0      0      0      0      0      0      0
# 10 Cloverfield Lane             0      0      0      0      0      0      0
# 10 Days in a Madhouse           0      0      0      0      0      0      0
# 10 Things I Hate About You      0      0      0      0      0      0      0
#
# movie_id                   19     20     22      ... 396152 402515 407887  \
# title                                            ...
# #Horror                         0      0      0  ...      0      0      0
# (500) Days of Summer            0      0      0  ...      0      0      0
# 10 Cloverfield Lane             0      0      0  ...      0      0      0
# 10 Days in a Madhouse           0      0      0  ...      0      0      0
# 10 Things I Hate About You      0      0      0  ...      0      0      0
#
# ...

# %%
data=pd.read_csv('movie.csv')
print(data)
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %% [markdown]
# # ALGORITHMS CASES

# %%
data.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot.bar()
# Out:
# <AxesSubplot:>

# %%
from matplotlib import pyplot as plt
x= ['a','b','c','d','e']
y=[9,8,5,4,3]
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.scatter(x,y)
plt.xlabel("movie")
plt.ylabel("title")
# Out:
# Text(0, 0.5, 'title')

# %%
plt.hist(y)
# Out:
# (array([1., 1., 0., 1., 0., 0., 0., 0., 1., 1.]),
#  array([3. , 3.6, 4.2, 4.8, 5.4, 6. , 6.6, 7.2, 7.8, 8.4, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x)
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 1., 0., 1.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
plt.plot(x,y)

# %%
plt.pie(y)
plt.show()
